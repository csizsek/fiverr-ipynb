# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
from matplotlib import pyplot as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
d = pd.read_csv('fiverrUsersPic_analyze_ALL_Animation_and_3D.csv', sep='\t')

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28282 entries, 0 to 28281
# Data columns (total 30 columns):
# Unnamed: 0             28282 non-null int64
# user_id                28282 non-null object
# gender                 28282 non-null object
# gender_confidence      28282 non-null float64
# race                   28282 non-null object
# race_confidence        28282 non-null float64
# age_value              28282 non-null int64
# age_range              28282 non-null int64
# smiling                28282 non-null float64
# category               28282 non-null object
# position               28282 non-null object
# url                    12285 non-null object
# gig_categories         28282 non-null object
# languages              28282 non-null object
# overall_rating         28282 non-null float64
# num_reviews            28282 non-null int64
# num_projects           28282 non-null int64
# country                28270 non-null object
# ...

# %%
d.describe().T
# Out:
#                      count        mean         std    min      25%      50%  \
# Unnamed: 0           28282     14140.5    8164.454      0  7070.25  14140.5
# gender_confidence    28282    18.48642    39.14904     -1       -1       -1
# race_confidence      28282    17.05545    36.68895     -1       -1       -1
# age_value            28282    5.360583    13.66266     -1       -1       -1
# age_range            28282   0.6248497    3.377228     -1       -1       -1
# smiling              28282    10.13944    27.67589     -1       -1       -1
# overall_rating       28282   0.4594972    1.414552      0        0        0
# num_reviews          28282     17.4506    192.7999     -2        0        0
# num_projects         28282   0.6002758    2.265236      0        0        0
# verified-e_mail      28282   0.9992928  0.02658361  False        1        1
# verified_twitter     28282           0           0  False        0        0
# ...

# %%
d.position[:20]
# Out:
# 0     seller
# 1      buyer
# 2      buyer
# 3      buyer
# 4      buyer
# 5      buyer
# 6      buyer
# 7      buyer
# 8      buyer
# 9      buyer
# 10     buyer
# 11     buyer
# 12     buyer
# 13     buyer
# 14     buyer
# 15     buyer
# 16     buyer
# 17     buyer
# 18     buyer
# 19     buyer
# Name: position, dtype: object

# %%
d.position.value_counts()
# Out:
# buyer     27101
# seller     1181
# dtype: int64

# %%
d[:5].T
# Out:
#                                                                      0  \
# Unnamed: 0                                                           0
# user_id                                                         cwiney
# gender                                                          Female
# gender_confidence                                              82.7996
# race                                                             Asian
# race_confidence                                                97.2983
# age_value                                                           32
# age_range                                                            7
# smiling                                                        72.1744
# category                                                Animation & 3D
# position                                                        seller
# url                  https://cdnil1.fiverrcdn.com/photos/679760/ori...
# ...

# %%
d.num_projects.corr(d.num_reviews)
# Out:
# 0.33479355328725391

# %%
_ = plt.hist(d.num_reviews[d.num_reviews > 1].values, bins=50)
